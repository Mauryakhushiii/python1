# %%
#task 1
playlist_ids = [101,567,345,980,123]
print(playlist_ids)
# Out:
# [101, 567, 345, 980, 123]

# %%
playlist_ids = [101,567,345,980,123]
playlist_ids.append(450)
playlist_ids.extend([432,890])
print(playlist_ids)
# Out:
# [101, 567, 345, 980, 123, 450, 432, 890]

# %%
#task 3
playlist_ids = [101,567,345,980,123]
remove_id = playlist_ids.pop()
print("Remove ID:",remove_id)
print("Remaining playlist:",playlist_ids)
# Out:
# Remove ID: 123
# Remaining playlist: [101, 567, 345, 980]

# %%
insta_filters = ("Clarendon","Juno","Lark","Valencia")
print(insta_filters)
insta_filters[0] = "Ludwig"
# Out:
# ('Clarendon', 'Juno', 'Lark', 'Valencia')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 insta_filters = ("Clarendon","Juno","Lark","Valencia")
#       2 print(insta_filters)
# ----> 3 insta_filters[0] = "Ludwig"
#
# TypeError: 'tuple' object does not support item assignment

# %%
zomato_orders = ["Pizza","Burger","Biryani"]
ipl_teams = ("CSK","MI","RBC","KKR")
print("zomato orders:",zomato_orders)
print("IPL teams:",ipl_teams)
zomato_orders.append("Pasta")
print("Updated Zomato orders:",zomato_orders)
# Out:
# zomato orders: ['Pizza', 'Burger', 'Biryani']
# IPL teams: ('CSK', 'MI', 'RBC', 'KKR')
# Updated Zomato orders: ['Pizza', 'Burger', 'Biryani', 'Pasta']
