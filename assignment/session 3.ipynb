# %%
age = 21
haight = 165.1
name = "Khushi"
has_spotify = True

print("age =",age , "type," , type(age))
print("haight =", haight , "type," , type(haight))
print("name =" , name, "type,", type(name))
print("has_spotify =",has_spotify, "type," ,type(has_spotify))
# Out:
# age = 21 type, <class 'int'>
# haight = 165.1 type, <class 'float'>
# name = Khushi type, <class 'str'>
# has_spotify = True type, <class 'bool'>

# %%
def total_cart_amount(prices):
    total = 0
    for i in prices:
        total = total + float(i)
    return total

prices = ["199.9","49","350.75"]
print("Total Cart Amount = ", total_cart_amount(prices))
# Out:
# Total Cart Amount =  599.65

# %%
score = input("Enter your cricket score: ")
score = int(score)

if score >= 50:
    print("Half-century!")
else:
    print("Keep going!")
# Out:
# Enter your cricket score:  67
# Half-century!

# %%
is_premium = "Ture"
is_premium = (is_premium == "True")

print(is_premium)
print(type(is_premium))
# Out:
# False
# <class 'bool'>
