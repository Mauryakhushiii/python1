# %%
#Task 1
class Song:
    def __init__(self,title,artist,duration):
        self.title = title
        self.artist = artist
        self.duration = duration

song1 = Song("Tum Hi Ho","Arijit Singh",260)
print(song1.title)
print(song1.artist)
print(song1.duration)
# Out:
# Tum Hi Ho
# Arijit Singh
# 260

# %%
#Task 2
class Song:
    def __init__(self,title,artist,duration):
        self.title = title
        self.artist = artist
        self.duration = duration
    def play_perview(self):
        print(f"Playing 30-second perview of {self.title} by {self.artist}")
song1 = Song("Tum Hi Ho","Arijit Singh",260) 
song1.play_perview()
# Out:
# Playing 30-second perview of Tum Hi Ho by Arijit Singh

# %%
#Task 3
class Foodorder:
    def __init__(self,restaurant_name,items,total_price):
        self.restaurant_name = restaurant_name
        self.items = items
        self.total_price = total_price

order1 = Foodorder("Zomato",["Pizza","Garlic Bread","Deals"],500)
print(order1.restaurant_name)
print(order1.items)
print(order1.total_price)
# Out:
# Zomato
# ['Pizza', 'Garlic Bread', 'Deals']
# 500

# %%
#Task 4
class Foodorder:
    def __init__(self,restaurant_name,items,total_price):
        self.restaurant_name = restaurant_name
        self.items = items
        self.total_price = total_price
    def add_item(self,item_name,item_price):
        
       self.items.append(item_name)

       self.total_price = self.total_price +item_price

order1 = Foodorder("Zomato",["Pizza","Garlic Bread","Deals"],500)

order1.add_item("Burger",120)
order1.add_item("Cold drink",55)

print(order1.items)
print(order1.total_price)
# Out:
# ['Pizza', 'Garlic Bread', 'Deals', 'Burger', 'Cold drink']
# 675
