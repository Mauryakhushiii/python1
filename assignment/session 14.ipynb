# %%
#task1
file = open("playlist.text","w")

file.write("Tum Hi Ho\n")
file.write("Channa Mereya\n")
file.write("Agar Tum Sath Ho\n")
file.write("Kesariya\n")
file.write("Tera Yar Hoon Main\n")

file.close()

# %%
#task2


file = open("playlist.txt", "r")

for song in file:
    print(song.upper(), end="")

file.close()
# Out:
# TUM HI HO
# CHANNA MEREYA
# AGAR TUM SATH HO
# KESARIYA
# TERA YAR HOON MAIN

# %%
#task3
import pandas as pd
df = pd.read_csv("ipl_match_scores.csv")
print(df)
# Out:
#    Unnamed: 0  Match_ID Team1 Team2  Score Winner
# 0           0         1   CSK    MI    180    CSK
# 1           1         2    MI   RBC    195    RCB
# 2           2         3   RCB   KKR    172    KKR
# 3           3         4   KKR   RSH    165    SRH
# 4           4         5   SRH    GT    210     GT
# 5           5         6    GT   LSG    188    LSG
# 6           6         7   LSG   CSK    175    CSK
# 7           7         8   CSK    MI    200     MI

# %%
import json
movies = [
    {"title": "3 Idiots",
     "year": 2009,
     "rating" : 8.4},
    {"title": "Dangal",
     "year": 2016,
     "rating": 8.3},
    {"title": "Pk",
     "year" : 2014,
     "rating": 8.1}
]
with open("movies.json","w") as file:
    json.dump(movies,file,indent=4)

with open("movies.json","r")as file:
    movies = json.load(file)

for movie in movies:
        print(movie["title"],movie["rating"])
# Out:
# 3 Idiots 8.4
# Dangal 8.3
# Pk 8.1

# %%
# task5
from pathlib import Path
import json
file_path = Path("my_fav_apps.json")
if not file_path.exists():
    apps = [
        {"name": "Instagram",
         "category": "Social Media"},
        {"name" : "YouTube",
         "category": "Entertainment"},
        {"name" : "WhatsApp",
         "category" : "Communication",}
    ]
    with open (file_path,"w")as file:
        json.dump(apps,file,indent=4)
    print("File created successfully")
else:
    print("File already exists")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # task5
#       2 from pathlib import Path
#       3 import json
# ----> 4 file_path = path("my_fav_apps.json")
#       5 if not file_path.exists():
#       6     apps = [
#       7         {"name": "Instagram",
#
# NameError: name 'path' is not defined
