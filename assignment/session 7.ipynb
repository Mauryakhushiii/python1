# %%
#task 1
minutes = int(input("Enter your spotify listening time:" ))
if minutes > 120:
    print("You aur a true music fan!")
else:
    print("Keep listening")
# Out:
# Enter your spotify listening time: 180
# You aur a true music fan!

# %%
#task2
amount = int(input("Enter your Zomato order amount"))
if amount > 300:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Enter your Zomato order amount 450
# Eligible for free delivery

# %%
#task3
total = int(input("Enter your flipkart cart total:"))
if total > 2000:
    print("You get a 10% discount")
elif total > 1000:
    print("you get a 5% discount")
else:
    print("No discount available")
# Out:
# Enter your flipkart cart total: 1200
# you get a 5% discount

# %%
#task 4
points = int(input("Enter your IPL fantasy team points:  "))
if points > 800:
    print("Champion")
else:
    if points >= 500:
        print("Top performer")
    else:
        print("Keep trying")
