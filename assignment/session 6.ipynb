# %%
#task 1
insta_followers = {
    "khushi_20050412" : 1200,
    "ved_the_ghost" : 2500,
    "Anuj_maurya" : 4000,
    "Harshita_malakar" : 2000,
    "the_peeyush_maurya" : 3300
}
    
       
print(insta_followers)
# Out:
# {'khushi_20050412': 1200, 'ved_the_ghost': 2500, 'Anuj_maurya': 4000, 'Harshita_malakar': 2000, 'the_peeyush_maurya': 3300}

# %%
#task 2 
insta_followers = {
    "khushi_20050412" : 1200,
    "ved_the_ghost" : 2500,
    "Anuj_maurya" : 4000,
    "Harshita_malakar" : 2000,
    "the_peeyush_maurya" : 3300
}

extra = {"Riya_sharma" : 3000} 
insta_followers.update(extra)
insta_followers["khushi_20050412"] = 3000
del insta_followers["Harshita_malakar"]


print(insta_followers)
# Out:
# {'khushi_20050412': 3000, 'ved_the_ghost': 2500, 'Anuj_maurya': 4000, 'the_peeyush_maurya': 3300, 'Riya_sharma': 3000}

# %%
# task 3
food_prices = {
    "Pizza" : 250,
    "Pasta" : 150,
    "Burger" : 200,
    "biryani" : 300,
    "Momos" : 250,
}
for item, price in food_prices.items():
    if price > 200:
        print(item, price)
# Out:
# Pizza 250
# biryani 300
# Momos 250

# %%
# task 4
flipkart_users = {"Sneha", "Anuj", "Anchal", "Prince", "khushi"}
myntra_users = {"khushi", "nidhi", "harsita","Sneha","Anchal"}
common_users = flipkart_users.intersection(myntra_users)
print(common_users)
# Out:
# {'Sneha', 'khushi', 'Anchal'}

# %%
#task 5
spotify_playlist1 = {"Arijit singh", "Shreya ghoshal", "Atif aslam"}
spotify_playlist2 = {"Lata mangeshkar", "Neha kakkar", "Arijit singh"}
def get_unique_artists( spotify_playlist1 ,spotify_playlist2):

   return spotify_playlist1.union(spotify_playlist2)
unique_artists = get_unique_artists(spotify_playlist1, spotify_playlist2)
print(unique_artists)
# Out:
# {'Shreya ghoshal', 'Atif aslam', 'Neha kakkar', 'Lata mangeshkar', 'Arijit singh'}
